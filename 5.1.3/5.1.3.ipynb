# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import numpy             as np
# %matplotlib widget

Ia1  = np.array([0.08, .08, .28, 2.64, 18, 69.1, 129.2, 172.5, 194,  194.7, 183.1, 161.6, 139.7, 121.8, 113.9, 102.7, 94.7, 89.8, 85.5, 81.8, 79.5, 77,  75.6, 73.7, 72.7, 71.5, 71.5, 70.9, 70.4, 70.2, 70.5, 70.7, 71.2, 72.2, 73.53, 74.4, 75.15, 77.3, 79, 80.8, 83.2, 86.1, 88.8, 91.4, 93.7, 96.7, 103,  113.6, 122.2, 129.6, 133.3, 152]) / 100
Uks1 = np.array([0,    .18, .41, .61,  .8, 1.02, 1.22,  1.41,  1.61, 1.81,  2.01,  2.3,   2.6,   2.92,  3.1,   3.42,  3.7,  3.9,  4.1,  4.3,  4.5,  4.7, 4.91, 5.1,  5.2,  5.4,  5.6,  5.8,  6,    6.2,  6.41, 6.82, 7.01, 7.2,  7.4,    7.5, 7.6,   7.8,  8,  8.21, 8.4,  8.61, 8.8,  9,    9.22, 9.4,  9.61, 9.8,   10,    10.3,  10.6,  11.2])

fig, ax = plt.subplots(figsize=(10,8), dpi=300)

plt.plot(Uks1, Ia1, zorder=-1)
plt.scatter(Uks1, Ia1, c='k', zorder=1)

ax.grid(which='major')
ax.minorticks_on()
ax.grid(which='minor', linestyle=':')
ax.set_title('V накала = 2.8 В')
ax.set_xlabel('Напряжение катод-сетка (ускоряющее) $V_{катод-сетка}$, В')
ax.set_ylabel('Ток анода, мА')

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_15474/986079543.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
Ia2  = np.array([.09, .09,  .09, .1,  .13, .24, .36, .65, 1.1, 2,   3.30,  7.07, 10.6, 18.3, 27.3, 37.5, 61.7, 93.5, 147.3, 168.8, 179.3, 184,  186,  185,  179.5, 167,  162.5, 147.6, 129.2, 107.5, 93,  78.3, 65.5, 56.1, 51.5, 44.4, 40.9, 37,  34.4, 32.8, 30,   29.5, 29.5, 29.7, 29.5, 29.6, 30.4, 31.4, 32.3, 33.8, 34.9, 39,   44.4, 47.5, 48.2,  50.3,  55.9,  65.1]) / 100
Uks2 = np.array([0,   0.12, 0.2, .32, .4,  .5,  .55, .6,  .65, 0.7, 0.743, 0.81, 0.85, 0.91, 0.96, 1,    1.1,  1.2,  1.4,   1.52,  1.62,  1.68, 1.78, 1.84, 1.93,  2.07, 2.11,  2.25,  2.4,   2.62,  2.8, 3.03, 3.32, 3.6,  3.82, 4.2,  4.5,  4.9, 5.3,  5.62, 6.15, 6.5,  6.9,  7.5,  7.62, 7.9,  8.2,  8.5,  8.7,  9,    9.3,  9.63, 9.9,  10.3, 10.52, 10.76, 11.03, 11.58])

ig, ax = plt.subplots(figsize=(10,8), dpi=300)

plt.plot(Uks2, Ia2, zorder=-1)
plt.scatter(Uks2, Ia2, zorder=1, c='k')

ax.grid(which='major')
ax.minorticks_on()
ax.grid(which='minor', linestyle=':')
ax.set_title('V накала = 2.5 В')
ax.set_ylabel('Ток анода, мА')
ax.set_xlabel('Напряжение катод-сетка (ускоряющее) $V_{катод-сетка}$, В')

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_15474/3557325043.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
Ia2  = np.array([.09, .09,  .09, .1,  .13, .24, .36, .65, 1.1, 2,   3.30,  7.07, 10.6, 18.3, 27.3, 37.5, 61.7, 93.5, 147.3, 168.8, 179.3, 184,  186,  185,  179.5, 167,  162.5, 147.6, 129.2, 107.5, 93,  78.3, 65.5, 56.1, 51.5, 44.4, 40.9, 37,  34.4, 32.8, 30,   29.5, 29.5, 29.7, 29.5, 29.6, 30.4, 31.4, 32.3, 33.8, 34.9, 39,   44.4, 47.5, 48.2,  50.3,  55.9,  65.1]) / 100
Uks2 = np.array([0,   0.12, 0.2, .32, .4,  .5,  .55, .6,  .65, 0.7, 0.743, 0.81, 0.85, 0.91, 0.96, 1,    1.1,  1.2,  1.4,   1.52,  1.62,  1.68, 1.78, 1.84, 1.93,  2.07, 2.11,  2.25,  2.4,   2.62,  2.8, 3.03, 3.32, 3.6,  3.82, 4.2,  4.5,  4.9, 5.3,  5.62, 6.15, 6.5,  6.9,  7.5,  7.62, 7.9,  8.2,  8.5,  8.7,  9,    9.3,  9.63, 9.9,  10.3, 10.52, 10.76, 11.03, 11.58])

ig, ax = plt.subplots(figsize=(10,8), dpi=300)

plt.plot(Uks2, -np.log(Ia2), zorder=-1)
plt.scatter(Uks2, -np.log(Ia2), zorder=1, c='k')

ax.grid(which='major')
ax.minorticks_on()
ax.grid(which='minor', linestyle=':')
ax.set_title('V накала = 2.5 В')
ax.set_ylabel(r'$ \omega(V) $ ~ -ln($I_a$), $I_a$ в мА')
ax.set_xlabel('Напряжение катод-сетка (ускоряющее) $V_{катод-сетка}$, В')


plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_15474/1359778609.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
