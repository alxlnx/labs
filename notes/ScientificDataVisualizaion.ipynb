# %%
# %matplotlib inline
import scipy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import ruler
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.style.use('./mystyle.txt')
fig = plt.figure(linewidth=1)
ax  = plt.subplot(1,1,1, aspect=1)
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
ax.plot(X, C, zorder=-100)
ax.plot(X, S, zorder=-200)
ax.set_yticks( [-1, 0, 1] )
# Out:
# [<matplotlib.axis.YTick at 0x7f37836f5a60>,
#  <matplotlib.axis.YTick at 0x7f3783733970>,
#  <matplotlib.axis.YTick at 0x7f37836dca60>]
